# %% [markdown]
# <a href="https://colab.research.google.com/github/prieto-daniel/Data-Science-I/blob/main/Test/test_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/prieto-daniel/Data-Science-I/refs/heads/main/Datos/TH.csv?token=GHSAT0AAAAAADDOZ5WYLBJGW2KB5J3W2YPC2A3O6SA'
df = pd.read_csv(url, delimiter=';')
df = df[df['PERIODO'] >= 202301]
df.head()
# Out:
#          ID                        AGENTE             CANAL SEGMENTO  ESTADO  \
# 0  QjAyMDM=  Q09SUkVPIExBIFBMQVRBIC0gMw==  Agte Corporativo        -  ACTIVO
# 1  QjA1NDA=      Q09SUkVPIENMQVJPTUVDTw==  Agte Corporativo        -  ACTIVO
# 2  QjA1NDA=      Q09SUkVPIENMQVJPTUVDTw==  Agte Corporativo        -  ACTIVO
# 3  QjA1NDA=      Q09SUkVPIENMQVJPTUVDTw==  Agte Corporativo        -  ACTIVO
# 4  QjA1NDk=          Q09SUkVPIENBUkhVRQ==  Agte Corporativo      3.B  ACTIVO
#
#        ZONA     PROVINCIA  PERIODO  BP  PEICI  PEICO  IOB  IIB
# 0      AMBA  BUENOS AIRES   202405   0      0      0    0    1
# 1  INTERIOR  BUENOS AIRES   202403   0      0      0   10    4
# 2  INTERIOR  BUENOS AIRES   202404   0      0      0    6    2
# 3  INTERIOR  BUENOS AIRES   202405   0      0      0    6    1
# 4  INTERIOR  BUENOS AIRES   202403   0      0      0   13    9

# %%
provincias:list[str] = df['PROVINCIA'].unique()
periodos:list[int] = df['PERIODO'].unique()
bp:list[int] = []

for provincia in provincias:
    datos_provincia:list[int] = df[df['PROVINCIA'] == provincia]['BP'].astype(int)
    #print(datos_provincia.head())
    bp.append(sum(datos_provincia))

data = {
    "PROVINCIA" : provincias,
    "BP" : bp
}

dataset = pd.DataFrame(data)

dataset.head()
# Out:
#              PROVINCIA        BP
# 0         BUENOS AIRES  68601043
# 1      CAPITAL FEDERAL  21948714
# 2           ENTRE RIOS   4298052
# 3  SANTIAGO DEL ESTERO   3850512
# 4                CHACO   2785092

# %%
# Visualizar los datos
plt.figure(figsize = (16, 9))
sns.set_style("darkgrid")
ax = sns.barplot(x = "PROVINCIA", y = "BP", data = df, estimator = 'sum')
#plt.title('Movimientos por Provincia', fontsize = 16)
plt.xlabel('PROVINCIAS', fontsize = 10)
plt.ylabel('MOVIMIENTOS', fontsize = 10)
plt.xticks(rotation = 45, ha = 'right')
plt.tight_layout()
ax.bar_label(ax.containers[0], fmt='{:,.0f}', fontsize=8)

plt.show()
